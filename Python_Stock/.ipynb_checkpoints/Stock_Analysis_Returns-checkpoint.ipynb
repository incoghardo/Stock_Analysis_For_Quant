# %% [markdown]
# # Stock Analysis Returns

# %%
# Library
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

import yfinance as yf
yf.pdr_override()

# %%
start = '2016-01-01'
end = '2019-01-01'

market = 'SPY'
symbol1 = 'AAPL'
symbol2 = 'MSFT'
symbol3 = 'AMD'
symbol4 = 'INTC'
bench = yf.download(market, start=start, end=end)
stock1 = yf.download(symbol1, start=start, end=end)
stock2 = yf.download(symbol2, start=start, end=end)
stock3 = yf.download(symbol3, start=start, end=end)
stock4 = yf.download(symbol4, start=start, end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Calculate Daily Gains

# %%
#Daily gain for the stock
stock1["Gain"]=(stock1["Adj Close"].pct_change())*100
stock2["Gain"]=(stock2["Adj Close"].pct_change())*100
stock3["Gain"]=(stock3["Adj Close"].pct_change())*100
stock4["Gain"]=(stock4["Adj Close"].pct_change())*100

# %% [markdown]
# ## Calculate the Mean and Variances of Daily Gains

# %%
print('Stock '+ symbol1 + ' Mean:', stock1["Gain"].mean())
print('Stock '+ symbol1 + ' Variances:', stock1["Gain"].var())
# Out:
# Stock AAPL Mean: 0.0717615985427602
# Stock AAPL Variances: 2.2250632971471664

# %%
print('Stock '+ symbol2 + ' Mean:', stock2["Gain"].mean())
print('Stock '+ symbol2 + ' Variances:', stock2["Gain"].var())
# Out:
# Stock MSFT Mean: 0.10088952806766234
# Stock MSFT Variances: 2.0235957807995284

# %%
print('Stock '+ symbol3 + ' Mean:', stock3["Gain"].mean())
print('Stock '+ symbol3 + ' Variances:', stock3["Gain"].var())
# Out:
# Stock AMD Mean: 0.3445908776318635
# Stock AMD Variances: 19.33307951072237

# %%
print('Stock '+ symbol4 + ' Mean:', stock4["Gain"].mean())
print('Stock '+ symbol4 + ' Variances:', stock4["Gain"].var())
# Out:
# Stock INTC Mean: 0.0670642767770045
# Stock INTC Variances: 2.5783493636045245

# %% [markdown]
# ## Highest volatality and draw the histogram distribution of daily returns for all the stock

# %%
sns.set(rc={"figure.figsize": (15, 10)});
sns.distplot(stock1['Gain'], hist = False, color = 'b' )
sns.distplot(stock2['Gain'], hist = False, color = 'r' )
sns.distplot(stock3['Gain'], hist = False, color = 'g' )
sns.distplot(stock4['Gain'], hist = False, color = 'y' )

# %% [markdown]
# ## Correlation

# %%
All_Stocks = pd.concat([stock1['Gain'],stock2['Gain'],stock3['Gain'],stock4['Gain']], axis=1)

# %%
names = ['AAPL', 'MSFT', 'AMD', 'INTC']
All_Stocks.columns = names

# %%
All_Stocks = All_Stocks.dropna()
All_Stocks
# Out:
#                 AAPL      MSFT       AMD      INTC
# Date
# 2016-01-05 -2.505933  0.456215 -0.722021 -0.470753
# 2016-01-06 -1.956956 -1.816535 -8.727273 -2.216929
# 2016-01-07 -4.220465 -3.478269 -9.163347 -3.748488
# 2016-01-08  0.528750  0.306710 -6.140345 -1.036452
# 2016-01-11  1.619239 -0.057347  9.345785  1.745478
# ...              ...       ...       ...       ...
# 2018-12-24 -2.587400 -4.173874 -1.653873 -2.787695
# 2018-12-26  7.042150  6.830981  7.507508  5.964674
# 2018-12-27 -0.648976  0.616559 -2.290502  0.368056
# 2018-12-28  0.051242 -0.780800  1.886792  0.841235
# 2018-12-31  0.966527  1.175414  3.591467  0.385020
#
# [753 rows x 4 columns]

# %%
All_Stocks.corr()
# Out:
#           AAPL      MSFT       AMD      INTC
# AAPL  1.000000  0.587342  0.270291  0.479345
# MSFT  0.587342  1.000000  0.200653  0.603708
# AMD   0.270291  0.200653  1.000000  0.264619
# INTC  0.479345  0.603708  0.264619  1.000000

# %%
#Heat map
sns.set(rc={"figure.figsize": (6, 4)});
sns.heatmap( All_Stocks.corr())

# %% [markdown]
# ### Monthly Returns

# %%
Stock1_Monthly = stock1.asfreq('M').ffill()
Stock2_Monthly = stock2.asfreq('M').ffill()
Stock3_Monthly = stock3.asfreq('M').ffill()
Stock4_Monthly = stock4.asfreq('M').ffill()

# %%
print('Monthly Returns')
print('Stock '+ symbol1 + ' Mean:', Stock1_Monthly["Gain"].mean())
print('Stock '+ symbol1 + ' Variances:', Stock1_Monthly["Gain"].var())
# Out:
# Monthly Returns
# Stock AAPL Mean: 0.2862633012792079
# Stock AAPL Variances: 0.722728232453935

# %%
print('Monthly Returns')
print('Stock '+ symbol2 + ' Mean:', Stock2_Monthly["Gain"].mean())
print('Stock '+ symbol2 + ' Variances:', Stock2_Monthly["Gain"].var())
# Out:
# Monthly Returns
# Stock MSFT Mean: 0.21547356082798533
# Stock MSFT Variances: 1.141210677566756

# %%
print('Monthly Returns')
print('Stock '+ symbol3 + ' Mean:', Stock3_Monthly["Gain"].mean())
print('Stock '+ symbol3 + ' Variances:', Stock3_Monthly["Gain"].var())
# Out:
# Monthly Returns
# Stock AMD Mean: 0.32642983441889606
# Stock AMD Variances: 7.488705232130907

# %%
print('Monthly Returns')
print('Stock '+ symbol4 + ' Mean:', Stock4_Monthly["Gain"].mean())
print('Stock '+ symbol4 + ' Variances:', Stock4_Monthly["Gain"].var())
# Out:
# Monthly Returns
# Stock INTC Mean: 0.14083705765732876
# Stock INTC Variances: 2.122321525617993

# %% [markdown]
# ## Monthly Returns with Box Plot

# %%
Stock1=np.array(Stock1_Monthly["Gain"])
Stock1= Stock1[~np.isnan(Stock1_Monthly["Gain"])]

Stock2 = np.array(Stock2_Monthly["Gain"])
Stock2=Stock2[~np.isnan(Stock2_Monthly["Gain"])]

Stock3 = np.array(Stock3_Monthly["Gain"])
Stock3=Stock3[~np.isnan(Stock3_Monthly["Gain"])]

Stock4 = np.array(Stock4_Monthly["Gain"])
Stock4=Stock4[~np.isnan(Stock4_Monthly["Gain"])]

AllStocks =[Stock1,Stock2,Stock3,Stock4]

# %%
fig = plt.figure(1, figsize=(20, 10))
ax = fig.add_subplot(111)
bp = ax.boxplot(AllStocks)
ax.set_xticklabels([symbol1, symbol2, symbol3, symbol4])
# Out:
# [Text(0, 0, 'AAPL'), Text(0, 0, 'MSFT'), Text(0, 0, 'AMD'), Text(0, 0, 'INTC')]

# %% [markdown]
# ## Stock with highest probability gains with 2% or more

# %%
#Probability of Stock1
stock1_p = 1-stats.norm.cdf( 0.02,
             loc=Stock1_Monthly["Gain"].mean(),
             scale=Stock1_Monthly["Gain"].std())

print(symbol1 + " probability of gains:", round(stock1_p, 2))
# Out:
# AAPL probability of gains: 0.62

# %%
stock2_p = 1-stats.norm.cdf( 0.02,
             loc=Stock2_Monthly["Gain"].mean(),
             scale=Stock2_Monthly["Gain"].std())

print(symbol2 + " probability of gains:", round(stock2_p, 2))
# Out:
# MSFT probability of gains: 0.57

# %%
stock3_p = 1-stats.norm.cdf( 0.02,
             loc=Stock3_Monthly["Gain"].mean(),
             scale=Stock3_Monthly["Gain"].std())

print(symbol3 + " probability of gains:", round(stock3_p, 2))
# Out:
# AMD probability of gains: 0.54

# %%
stock4_p = 1-stats.norm.cdf( 0.02,
             loc=Stock4_Monthly["Gain"].mean(),
             scale=Stock4_Monthly["Gain"].std())

print(symbol4 + " probability of gains:", round(stock4_p, 2))
# Out:
# INTC probability of gains: 0.53

# %% [markdown]
# ## Stock with highest probability of loss with 2% or more

# %%
#Probability of Stock1
stock1_l = stats.norm.cdf(-0.02,
             loc=Stock1_Monthly["Gain"].mean(),
             scale=Stock1_Monthly["Gain"].std())

print(symbol1 + " probability of loss:", round(stock1_l, 2))
# Out:
# AAPL probability of loss: 0.36

# %%
stock2_l = stats.norm.cdf(-0.02,
             loc=Stock2_Monthly["Gain"].mean(),
             scale=Stock2_Monthly["Gain"].std())

print(symbol2 + " probability of loss:", round(stock2_l, 2))
# Out:
# MSFT probability of loss: 0.41

# %%
stock3_l = stats.norm.cdf(-0.02,
             loc=Stock3_Monthly["Gain"].mean(),
             scale=Stock3_Monthly["Gain"].std())

print(symbol3 + " probability of loss:", round(stock3_l, 2))
# Out:
# AMD probability of loss: 0.45

# %%
stock4_l = stats.norm.cdf(-0.02,
             loc=Stock4_Monthly["Gain"].mean(),
             scale=Stock4_Monthly["Gain"].std())

print(symbol4 + " probability of loss:", round(stock4_l, 2))
# Out:
# INTC probability of loss: 0.46

# %% [markdown]
# ## Portfolio Analysis

# %%
x=np.array([Stock1_Monthly["Gain"].mean(),Stock2_Monthly["Gain"].mean(),Stock3_Monthly["Gain"].mean(),Stock4_Monthly["Gain"].mean()])
print(x)
# Out:
# [0.2862633  0.21547356 0.32642983 0.14083706]

# %%
#Weights of the stocks is 0.25 which is added up to 1
weights = np.array([0.25,0.25,0.25,0.25])
exp_val=np.sum(x*weights)

print("Expected Value is ",round(exp_val,4))
print("\n")
#Calculate Covariance matrix
y = np.vstack([Stock1,Stock2,Stock3,Stock4])

cov = np.cov(y)
print("Below is covariance matrix")
print("\n")
print(cov)
# Out:
# Expected Value is  0.2423
#
#
# Below is covariance matrix
#
#
# [[0.72272823 0.35454057 0.72956025 0.3469822 ]
#  [0.35454057 1.14121068 1.49466066 0.49113678]
#  [0.72956025 1.49466066 7.48870523 0.32942308]
#  [0.3469822  0.49113678 0.32942308 2.12232153]]

# %%
#Calcualte the variance of monthly return of portfolio
covar=np.dot(weights.T,np.dot(cov,weights))
print("Variance of portfolio is ",round(covar,4))
# Out:
# Variance of portfolio is  1.1855

# %%
#Calculate the probability
1-stats.norm.cdf(0.005,
             loc=exp_val,
             scale=covar)
# Out:
# 0.5793112594080382

# %%
# Create 25 Iteration of weights
# Generate a random number

number=range(1,26)

# %%
# Function to calculate expected value of portfolio and variance
def calculate(weights, meanReturns, covMatrix):
     
     portReturn = np.sum(weights*meanReturns)
     portVar = (np.dot(weights.T, np.dot(covMatrix, weights)))
     return portReturn, portVar

# %%
# Generate weights in random that sum to 1 
import random
random.seed(4)
d=[]
for i in number:
    weights = np.random.random(4)
    weights /= weights.sum()
    print("Set of random weight for Iterartion-->",i,"is", weights)
    pret, pvar = calculate(weights, x, cov)
    
    d.append((weights[0],weights[1],weights[2],weights[3],pret,pvar))
    df=pd.DataFrame(d,columns=('Stock1_weight','Stock2_weight','Stock3_weight','Stock4_weight','mean_return','var_return'))
    print("Mean monthly return for iteration-->",i,"is",pret)
    print("Variance of monthly return for iteration-->",i,"is",pvar)
    print("\n")
# Out:
# Set of random weight for Iterartion--> 1 is [0.15568853 0.01962062 0.38609536 0.43859549]
# Mean monthly return for iteration--> 1 is 0.23659917950234438
# Variance of monthly return for iteration--> 1 is 1.8224871879445748
#
#
# Set of random weight for Iterartion--> 2 is [0.19094388 0.23474217 0.2340872  0.34022676]
# Mean monthly return for iteration--> 2 is 0.22957053646766096
# Variance of monthly return for iteration--> 2 is 1.1825309505956705
#
#
# Set of random weight for Iterartion--> 3 is [0.24291888 0.29699866 0.23161283 0.22846963]
# Mean monthly return for iteration--> 3 is 0.2413164472958626
# Variance of monthly return for iteration--> 3 is 1.1347365385638533
#
#
# Set of random weight for Iterartion--> 4 is [0.05384901 0.43345514 0.08471144 0.42798442]
# Mean monthly return for iteration--> 4 is 0.19674152342935364
# Variance of monthly return for iteration--> 4 is 1.014070458178045
#
#
# Set of random weight for Iterartion--> 5 is [0.09290965 0.13781677 0.4980745  0.27119908]
# Mean monthly return for iteration--> 5 is 0.25707375002033306
# Variance of monthly return for iteration--> 5 is 2.4667852291813848
#
#
# Set of random weight for Iterartion--> 6 is [0.23974211 0.10943038 0.30474183 0.34608569]
# Mean monthly return for iteration--> 6 is 0.24042723378805264
# Variance of monthly return for iteration--> 6 is 1.394025107627607
#
#
# Set of random weight for Iterartion--> 7 is [0.08024305 0.35911809 0.08397376 0.47666509]
# Mean monthly return for iteration--> 7 is 0.19489474591711875
# Variance of monthly return for iteration--> 7 is 1.0283228029220461
#
#
# Set of random weight for Iterartion--> 8 is [0.22249157 0.21654335 0.16000581 0.40095927]
# Mean monthly return for iteration--> 8 is 0.21905113144288502
# Variance of monthly return for iteration--> 8 is 1.0013617141565687
#
#
# Set of random weight for Iterartion--> 9 is [0.61577009 0.02914273 0.07482571 0.28026147]
# Mean monthly return for iteration--> 9 is 0.2464484119145371
# Variance of monthly return for iteration--> 9 is 0.7117116130466268
#
#
# Set of random weight for Iterartion--> 10 is [0.00281896 0.19343895 0.66608456 0.13765754]
# Mean monthly return for iteration--> 10 is 0.27930509752901705
# Variance of monthly return for iteration--> 10 is 3.8805558793547137
#
#
# Set of random weight for Iterartion--> 11 is [0.25897224 0.01905323 0.30147877 0.42049576]
# Mean monthly return for iteration--> 11 is 0.23587276697410317
# Variance of monthly return for iteration--> 11 is 1.406344078948706
#
#
# Set of random weight for Iterartion--> 12 is [0.18085926 0.30368167 0.29483104 0.22062804]
# Mean monthly return for iteration--> 12 is 0.24452298868798486
# Variance of monthly return for iteration--> 12 is 1.403910530872803
#
#
# Set of random weight for Iterartion--> 13 is [0.19498225 0.535216   0.05777591 0.21202584]
# Mean monthly return for iteration--> 13 is 0.219862035691516
# Variance of monthly return for iteration--> 13 is 0.8058914037981995
#
#
# Set of random weight for Iterartion--> 14 is [0.34548773 0.09761509 0.37688952 0.18000766]
# Mean monthly return for iteration--> 14 is 0.2683136623583274
# Variance of monthly return for iteration--> 14 is 1.6586481345604833
#
#
# Set of random weight for Iterartion--> 15 is [0.08479336 0.27616295 0.0130017  0.62604198]
# Mean monthly return for iteration--> 15 is 0.17619309700375824
# Variance of monthly return for iteration--> 15 is 1.1662688809374444
#
#
# Set of random weight for Iterartion--> 16 is [0.21690618 0.26005167 0.26382186 0.25922029]
# Mean monthly return for iteration--> 16 is 0.2407536873295319
# Variance of monthly return for iteration--> 16 is 1.2538939857802007
#
#
# Set of random weight for Iterartion--> 17 is [0.16093954 0.02386386 0.49088953 0.32430707]
# Mean monthly return for iteration--> 17 is 0.25712855625689307
# Variance of monthly return for iteration--> 17 is 2.3488850238885344
#
#
# Set of random weight for Iterartion--> 18 is [0.10395942 0.38089297 0.32341489 0.19173273]
# Mean monthly return for iteration--> 18 is 0.24440747155412107
# Variance of monthly return for iteration--> 18 is 1.6064965479375852
#
#
# Set of random weight for Iterartion--> 19 is [0.29341752 0.43198137 0.15756354 0.11703756]
# Mean monthly return for iteration--> 19 is 0.24499190001141352
# Variance of monthly return for iteration--> 19 is 0.9366132884784797
#
#
# Set of random weight for Iterartion--> 20 is [0.22288276 0.27307577 0.29677274 0.20726873]
# Mean monthly return for iteration--> 20 is 0.2487103574447583
# Variance of monthly return for iteration--> 20 is 1.3818525412070013
#
#
# Set of random weight for Iterartion--> 21 is [0.20101244 0.23459832 0.32195092 0.24243832]
# Mean monthly return for iteration--> 21 is 0.24733090555953902
# Variance of monthly return for iteration--> 21 is 1.4877345111853317
#
#
# Set of random weight for Iterartion--> 22 is [0.30542869 0.07460729 0.06846489 0.55149913]
# Mean monthly return for iteration--> 22 is 0.20352942209904523
# Variance of monthly return for iteration--> 22 is 0.9985094367934321
#
#
# Set of random weight for Iterartion--> 23 is [0.19817109 0.34119433 0.0991953  0.36143928]
# Mean monthly return for iteration--> 23 is 0.21353181754124356
# Variance of monthly return for iteration--> 23 is 0.8844420883295119
#
#
# Set of random weight for Iterartion--> 24 is [0.20011002 0.18217237 0.33683145 0.28088617]
# Mean monthly return for iteration--> 24 is 0.24604849784001376
# Variance of monthly return for iteration--> 24 is 1.5431242168436607
#
#
# Set of random weight for Iterartion--> 25 is [0.13372306 0.44728648 0.40249794 0.01649251]
# Mean monthly return for iteration--> 25 is 0.2683685098744248
# Variance of monthly return for iteration--> 25 is 2.127292044594526

# %%
# Dataframe containing stock weights,mean and variances of all possible portfolios
print(df)
# Out:
#     Stock1_weight  Stock2_weight  Stock3_weight  Stock4_weight  mean_return  \
# 0        0.155689       0.019621       0.386095       0.438595     0.236599
# 1        0.190944       0.234742       0.234087       0.340227     0.229571
# 2        0.242919       0.296999       0.231613       0.228470     0.241316
# 3        0.053849       0.433455       0.084711       0.427984     0.196742
# 4        0.092910       0.137817       0.498074       0.271199     0.257074
# 5        0.239742       0.109430       0.304742       0.346086     0.240427
# 6        0.080243       0.359118       0.083974       0.476665     0.194895
# 7        0.222492       0.216543       0.160006       0.400959     0.219051
# 8        0.615770       0.029143       0.074826       0.280261     0.246448
# 9        0.002819       0.193439       0.666085       0.137658     0.279305
# 10       0.258972       0.019053       0.301479       0.420496     0.235873
# 11       0.180859       0.303682       0.294831       0.220628     0.244523
# 12       0.194982       0.535216       0.057776       0.212026     0.219862
# 13       0.345488       0.097615       0.376890       0.180008     0.268314
# 14       0.084793       0.276163       0.013002       0.626042     0.176193
# 15       0.216906       0.260052       0.263822       0.259220     0.240754
# 16       0.160940       0.023864       0.490890       0.324307     0.257129
# 17       0.103959       0.380893       0.323415       0.191733     0.244407
# 18       0.293418       0.431981       0.157564       0.117038     0.244992
# 19       0.222883       0.273076       0.296773       0.207269     0.248710
# 20       0.201012       0.234598       0.321951       0.242438     0.247331
# 21       0.305429       0.074607       0.068465       0.551499     0.203529
# 22       0.198171       0.341194       0.099195       0.361439     0.213532
# 23       0.200110       0.182172       0.336831       0.280886     0.246048
# 24       0.133723       0.447286       0.402498       0.016493     0.268369
#
#     var_return
# 0     1.822487
# 1     1.182531
# 2     1.134737
# 3     1.014070
# 4     2.466785
# 5     1.394025
# 6     1.028323
# 7     1.001362
# 8     0.711712
# 9     3.880556
# 10    1.406344
# 11    1.403911
# 12    0.805891
# 13    1.658648
# 14    1.166269
# 15    1.253894
# 16    2.348885
# 17    1.606497
# 18    0.936613
# 19    1.381853
# 20    1.487735
# 21    0.998509
# 22    0.884442
# 23    1.543124
# 24    2.127292

# %%
fig = plt.figure(1, figsize=(20, 10))
plt.scatter(df.mean_return,df.var_return, c=df.var_return)
plt.colorbar()
fig.suptitle('Mean Return VS Volatility', fontsize=20)
plt.xlabel('Volatility', fontsize=18)
plt.ylabel('Mean Return', fontsize=16)
plt.show()
