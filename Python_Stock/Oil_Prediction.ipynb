# %% [markdown]
# # Oil Price Prediction Using Machine Learning

# %%
# LinearRegression is a machine learning library for linear regression 
from sklearn.linear_model import LinearRegression 

# pandas and numpy are used for data manipulation 
import pandas as pd 
import numpy as np 

# matplotlib and seaborn are used for plotting graphs 
import matplotlib.pyplot as plt 
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# fix_yahoo_finance is used to fetch data 
import yfinance as yf
yf.pdr_override()

# %%
# Read data 
Df = yf.download('USO','2016-01-01','2020-03-18')

# Only keep close columns 
Df=Df[['Close']] 

# Drop rows with missing values 
Df= Df.dropna() 

# Plot the closing price of GLD 
Df.Close.plot(figsize=(10,5)) 
plt.ylabel("OIL ETF Prices")
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Define explanatory variables
Df['S_3'] = Df['Close'].shift(1).rolling(window=3).mean() 
Df['S_9']= Df['Close'].shift(1).rolling(window=9).mean() 
Df= Df.dropna() 
X = Df[['S_3','S_9']] 
X.head()
# Out:
#                  S_3       S_9
# Date
# 2016-01-15  9.163333  9.798889
# 2016-01-19  9.036667  9.555555
# 2016-01-20  8.836666  9.314444
# 2016-01-21  8.506667  9.106667
# 2016-01-22  8.430000  8.957778

# %%
# Define dependent variable
y = Df['Close']
y.head()
# Out:
# Date
# 2016-01-15    8.79
# 2016-01-19    8.49
# 2016-01-20    8.24
# 2016-01-21    8.56
# 2016-01-22    9.27
# Name: Close, dtype: float64

# %%
# Split the data into train and test dataset
t=.8 
t = int(t*len(Df)) 

# Train dataset 
X_train = X[:t] 
y_train = y[:t]  

# Test dataset 
X_test = X[t:] 
y_test = y[t:]

# %%
# Create a linear regression model
# Y = m1 * X1 + m2 * X2 + C
# Gold ETF price = m1 * 3 days moving average + m2 * 15 days moving average + c
linear = LinearRegression().fit(X_train,y_train) 
print("MJ ETF Price =", round(linear.coef_[0],2), "* 3 Days Moving Average", round(linear.coef_[1],2), "* 9 Days Moving Average +", round(linear.intercept_,2))
# Out:
# MJ ETF Price = 1.25 * 3 Days Moving Average -0.26 * 9 Days Moving Average + 0.19

# %%
# Predicting the Oil ETF prices
predicted_price = linear.predict(X_test)  
predicted_price = pd.DataFrame(predicted_price,index=y_test.index,columns = ['price'])  
predicted_price.plot(figsize=(10,5))  
y_test.plot()  
plt.legend(['predicted_price','actual_price'])  
plt.ylabel("USO ETF Price")  
plt.show()

# %%
r2_score = linear.score(X[t:],y[t:])*100  
float("{0:.2f}".format(r2_score))
# Out:
# 89.69

# %% [markdown]
# Oil Stock

# %%
Oil_stock = ['PBR', 'VALE', 'RIG', 'WLL']

# %%
start = '2016-01-01'
end = '2018-09-10'
df = yf.download(Oil_stock,start,end)
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
stocks = pd.DataFrame(df['Adj Close'])
stocks.head()
# Out:
#                  PBR    RIG      VALE        WLL
# Date
# 2016-01-04  4.148249  12.55  2.823308  38.119999
# 2016-01-05  4.070348  12.15  2.814374  36.160000
# 2016-01-06  3.846381  11.52  2.599945  31.639999
# 2016-01-07  3.710054  11.00  2.421255  30.160000
# 2016-01-08  3.651628  10.75  2.322975  31.080000

# %%
plt.figure(figsize=(16,8))
plt.plot(stocks)
plt.title('Oil Stock Adj Close')
plt.legend(stocks)
plt.grid()
plt.ylabel('Price')
plt.xlabel('Date')
plt.show()

# %%
stocks.plot(grid = True, figsize=(12,8))

# %%
stock_return = stocks.apply(lambda x: x / x[0])
stock_return.head()
# Out:
#            Adj Close                                   Close            \
#                  PBR       RIG      VALE       WLL       PBR       RIG
# Date
# 2016-01-04  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2016-01-05  0.981221  0.968127  0.996835  0.948583  0.981221  0.968127
# 2016-01-06  0.927230  0.917928  0.920886  0.830011  0.927230  0.917928
# 2016-01-07  0.894366  0.876494  0.857595  0.791186  0.894366  0.876494
# 2016-01-08  0.880282  0.856574  0.822785  0.815320  0.880282  0.856574
#
#                                     High            ...       Low            \
#                 VALE       WLL       PBR       RIG  ...      VALE       WLL
# Date                                                ...
# 2016-01-04  1.000000  1.000000  1.000000  1.000000  ...  1.000000  1.000000
# 2016-01-05  0.996835  0.948583  0.966063  0.982512  ...  0.987302  0.964797
# 2016-01-06  0.920886  0.830011  0.918552  0.928458  ...  0.911111  0.854785
# 2016-01-07  0.857595  0.791186  0.895928  0.923688  ...  0.857143  0.803080
# 2016-01-08  0.822785  0.815320  0.895928  0.883943  ...  0.825397  0.804180
#
#                 Open                                  Volume            \
#                  PBR       RIG      VALE       WLL       PBR       RIG
# Date
# 2016-01-04  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2016-01-05  0.986111  1.000000  1.009464  0.996791  0.778074  0.922444
# 2016-01-06  0.937500  0.945617  0.940063  0.910160  1.192333  1.632342
# 2016-01-07  0.881944  0.896916  0.870662  0.796791  1.188110  1.263041
# 2016-01-08  0.909722  0.899351  0.880126  0.822460  1.020819  1.061150
#
#
#                 VALE       WLL
# Date
# 2016-01-04  1.000000  1.000000
# 2016-01-05  0.916977  1.117361
# 2016-01-06  2.011252  1.239901
# 2016-01-07  2.114877  1.303922
# 2016-01-08  2.007411  1.513284
#
# [5 rows x 24 columns]

# %%
stock_return.plot(grid = True, figsize=(12,8)).axhline(y = 1, color = "black", lw = 2)
plt.axhline(y=4, color = 'red', lw=2)

# %%
stock_return = stocks.pct_change(1).dropna()
stock_return.head()
# Out:
#                  PBR       RIG      VALE       WLL
# Date
# 2016-01-05 -0.018779 -0.031873 -0.003165 -0.051417
# 2016-01-06 -0.055024 -0.051852 -0.076190 -0.125000
# 2016-01-07 -0.035443 -0.045139 -0.068728 -0.046776
# 2016-01-08 -0.015748 -0.022727 -0.040591  0.030504
# 2016-01-11 -0.010667 -0.038140 -0.023077 -0.063063

# %%
stock_return.tail()
# Out:
#                  PBR       RIG      VALE       WLL
# Date
# 2018-08-31  0.035238 -0.005747  0.002278  0.011122
# 2018-09-04 -0.043238 -0.066887 -0.049242 -0.007857
# 2018-09-05  0.015385 -0.008850  0.005578  0.002376
# 2018-09-06  0.006629 -0.033036  0.029319 -0.059648
# 2018-09-07  0.038570  0.001847  0.001540 -0.008192

# %%
stock_return.plot(grid = True, figsize=(12,8)).axhline(y = 1, color = "black", lw = 2)

# %%
stock_change = stocks.apply(lambda x: np.log(x) - np.log(x.shift(1))) # shift moves dates back by 1.
stock_change.head()
# Out:
#                  PBR       RIG      VALE       WLL
# Date
# 2016-01-04       NaN       NaN       NaN       NaN
# 2016-01-05 -0.018958 -0.032392 -0.003170 -0.052786
# 2016-01-06 -0.056596 -0.053244 -0.079249 -0.133531
# 2016-01-07 -0.036086 -0.046189 -0.071204 -0.047906
# 2016-01-08 -0.015873 -0.022990 -0.041437  0.030048

# %%
stock_change.plot(grid = True, figsize=(12,8)).axhline(y = 0, color = "black", lw = 2)

# %%
sns.pairplot(stock_change[1:])

# %%
stock_change.idxmin()
# Out:
# PBR    2017-05-18
# RIG    2016-03-08
# VALE   2016-03-08
# WLL    2016-01-19
# dtype: datetime64[ns]

# %%
stock_change.idxmax()
# Out:
# PBR    2016-02-22
# RIG    2016-03-04
# VALE   2016-02-04
# WLL    2016-11-30
# dtype: datetime64[ns]

# %%
stock_change.std()
# Out:
# PBR     0.034048
# RIG     0.032994
# VALE    0.034225
# WLL     0.049464
# dtype: float64

# %%
# Sharpe Ratio for Each Stocks
N = 252
returns = stocks.pct_change().dropna()
annualised_sharpe = np.sqrt(N) * returns.mean() / returns.std()
annualised_sharpe
# Out:
# PBR     0.931726
# RIG     0.157730
# VALE    1.297335
# WLL     0.490911
# dtype: float64

# %%
annualised_sharpe.index
# Out:
# Index(['PBR', 'RIG', 'VALE', 'WLL'], dtype='object')

# %%
annualised_sharpe.sort_values()
# Out:
# RIG     0.157730
# WLL     0.490911
# PBR     0.931726
# VALE    1.297335
# dtype: float64

# %%
annualised_sharpe.sort_index()
# Out:
# PBR     0.931726
# RIG     0.157730
# VALE    1.297335
# WLL     0.490911
# dtype: float64

# %%
# Equity Sharpe - Buy and Hold
N = 252 # Number of trading in a year
risk = 0.01
excess_daily_ret =  returns - (risk * N)
equity_sharpe = np.sqrt(N) * excess_daily_ret.mean() / excess_daily_ret.std()
equity_sharpe.sort_values()
# Out:
# RIG    -1203.023762
# PBR    -1175.508739
# VALE   -1160.238341
# WLL     -800.001346
# dtype: float64

# %%
# Market Neutral Sharpe
start = '2016-01-01'
end = '2018-09-10'
market = 'SPY'
ticker = ['PBR', 'VALE', 'RIG', 'WLL']
bench = yf.download(market,start,end)
stocks = yf.download(ticker,start,end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  4 of 4 completed

# %%
tick = pd.DataFrame(stocks['Adj Close'])
tick.head()
# Out:
#                  PBR    RIG      VALE        WLL
# Date
# 2016-01-04  4.148249  12.55  2.823308  38.119999
# 2016-01-05  4.070348  12.15  2.814374  36.160000
# 2016-01-06  3.846381  11.52  2.599945  31.639999
# 2016-01-07  3.710054  11.00  2.421255  30.160000
# 2016-01-08  3.651628  10.75  2.322975  31.080000

# %%
daily_rets = tick.pct_change().dropna()
daily_rets.head()
# Out:
#                  PBR       RIG      VALE       WLL
# Date
# 2016-01-05 -0.018779 -0.031873 -0.003165 -0.051417
# 2016-01-06 -0.055024 -0.051852 -0.076190 -0.125000
# 2016-01-07 -0.035443 -0.045139 -0.068728 -0.046776
# 2016-01-08 -0.015748 -0.022727 -0.040591  0.030504
# 2016-01-11 -0.010667 -0.038140 -0.023077 -0.063063

# %%
bench_rets = bench['Adj Close'].pct_change().dropna()
bench_rets.head()
# Out:
# Date
# 2016-01-05    0.001691
# 2016-01-06   -0.012614
# 2016-01-07   -0.023992
# 2016-01-08   -0.010976
# 2016-01-11    0.000990
# Name: Adj Close, dtype: float64

# %%
strat = (daily_rets.sub(bench_rets, axis=0))/2
strat.head()
# Out:
#                  PBR       RIG      VALE       WLL
# Date
# 2016-01-05 -0.010235 -0.016782 -0.002428 -0.026554
# 2016-01-06 -0.021205 -0.019619 -0.031788 -0.056193
# 2016-01-07 -0.005726 -0.010574 -0.022368 -0.011392
# 2016-01-08 -0.002386 -0.005875 -0.014807  0.020740
# 2016-01-11 -0.005828 -0.019565 -0.012033 -0.032026

# %%
N = 252
market_neutral_sharpe = np.sqrt(N) * strat.mean() / strat.std()
market_neutral_sharpe.sort_values()
# Out:
# RIG    -0.152391
# WLL     0.304037
# PBR     0.687169
# VALE    1.089317
# dtype: float64
